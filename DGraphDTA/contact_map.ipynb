# %%
import os 
print(os.getcwd())
# Out:
# /home/ailon/Desktop/gimlet/Main_Model/DGraphDTA-master

# %%
os.chdir('/home/ailon/Desktop/gimlet/Main_Model/DGraphDTA-master')

# %%
print(os.getcwd())
# Out:
# /home/ailon/Desktop/gimlet/Main_Model/DGraphDTA-master

# %% [markdown]
# #### > def target_to_graph

# %%
contact_dir = 'cluster3/data/davis/pconsc4'
key = 'CDK11'
contact_file = os.path.join(contact_dir, key + '.npy')
print(contact_file)
# Out:
# cluster3/data/davis/pconsc4/CDK11.npy

# %%
import numpy as np 
contact_map = np.load(contact_file)

# %%
contact_map
# Out:
# array([[0.        , 0.99246097, 0.76768047, ..., 0.00668097, 0.00711751,
#         0.00751765],
#        [0.99246097, 0.        , 0.9985337 , ..., 0.00445229, 0.0047275 ,
#         0.00504957],
#        [0.76768047, 0.9985337 , 0.        , ..., 0.00384259, 0.00454247,
#         0.00530408],
#        ...,
#        [0.00668097, 0.00445229, 0.00384259, ..., 0.        , 0.83994097,
#         0.6033014 ],
#        [0.00711751, 0.0047275 , 0.00454247, ..., 0.83994097, 0.        ,
#         0.80859405],
#        [0.00751765, 0.00504957, 0.00530408, ..., 0.6033014 , 0.80859405,
#         0.        ]], dtype=float32)

# %%
contact_map += np.matrix(np.eye(contact_map.shape[0]))

# %%
contact_map
# Out:
# array([[1.        , 0.99246097, 0.76768047, ..., 0.00668097, 0.00711751,
#         0.00751765],
#        [0.99246097, 1.        , 0.9985337 , ..., 0.00445229, 0.0047275 ,
#         0.00504957],
#        [0.76768047, 0.9985337 , 1.        , ..., 0.00384259, 0.00454247,
#         0.00530408],
#        ...,
#        [0.00668097, 0.00445229, 0.00384259, ..., 1.        , 0.83994097,
#         0.6033014 ],
#        [0.00711751, 0.0047275 , 0.00454247, ..., 0.83994097, 1.        ,
#         0.80859405],
#        [0.00751765, 0.00504957, 0.00530408, ..., 0.6033014 , 0.80859405,
#         1.        ]], dtype=float32)

# %%
import pconsc4
# Out:
# Using TensorFlow backend.
# /home/ailon/anaconda3/envs/dta/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ailon/anaconda3/envs/dta/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ailon/anaconda3/envs/dta/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
model = pconsc4.get_pconsc4()
# Out:
# WARNING:tensorflow:From /home/ailon/anaconda3/envs/dta/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/ailon/anaconda3/envs/dta/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/ailon/anaconda3/envs/dta/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/ailon/anaconda3/envs/dta/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# ...

# %%
# Show pred_1 on the screen:

import matplotlib.pyplot as plt 
plt.figure(figsize=(10,10))
plt.imshow(pred_1['cmap'])

# %%
pred_2 = pconsc4.predict(model, '/home/ailon/Desktop/gimlet/Main_Model/DGraphDTA-master/cluster3/data/davis/aln/CDK2.aln')

# %%
# Show pred_2 on the screen:

import matplotlib.pyplot as plt 
plt.figure(figsize=(10,10))
plt.imshow(pred_2['cmap'])
